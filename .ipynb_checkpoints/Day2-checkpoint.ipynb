# %%
import os
import math
os.getcwd()
# Out:
# 'C:\\Users\\Pilar\\Documents\\AdventOfCode'

# %% [markdown]
# Determine which games would have been possible if the bag had been loaded with only 12 red cubes, 13 green cubes, and 14 blue cubes. What is the sum of the IDs of those games?

# %%
def ret_num(real):
    number_string=''
    num=0
    for char in real:
        print(char)
        if char.isdigit():
            number_string=number_string+char
            num=int(number_string)
    return num

# %%
def ret_real(col):
    real=col
    if ':'in col:
        real=(col.split(':'))[1]
    elif():
        real=col
    return real

# %%
def possible(game):
    take_out=game.split(';')
    number_string=''
    real=''
    print(game)
    print(take_out)
    for take in take_out:
        print(take)
        real=''
        colors=take.split(',')
        print(colors)
      # print(colors)
        for color in colors:
            real=ret_real(color)
            print(real)
            
            if 'green'in real:
                num=0
                num=ret_num(real)
                print('\nThe number of green cubes is: ', num)
                
                if num>13:
                    return False
                print('next ',real)
        
            elif 'red' in real:
                num=0
                num=ret_num(real)
                print('\nThe number of red cubes is: ', num)
                
                if num>12:
                    return False
                
            elif 'blue' in real:
                num=0
                num=ret_num(real)
                
                print('\nThe number of blue cubes is: ', num)
                if num>14:
                    return False
                
    return True

# %%
file = open('Day2.txt', 'r')

lines=file.readlines()
# lines=['Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green',
#     'Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue',
#     'Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red',
#     'Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red',
#     'Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green']
games_possible=[]

for (i,line) in enumerate(lines):
    #print(possible(line))
    if possible(line):
        games_possible.append(i+1)
games_possible
sum(games_possible)
# Out:
# Game 1: 4 green, 2 blue; 1 red, 1 blue, 4 green; 3 green, 4 blue, 1 red; 7 green, 2 blue, 4 red; 3 red, 7 green; 3 red, 3 green
#
# ['Game 1: 4 green, 2 blue', ' 1 red, 1 blue, 4 green', ' 3 green, 4 blue, 1 red', ' 7 green, 2 blue, 4 red', ' 3 red, 7 green', ' 3 red, 3 green\n']
# Game 1: 4 green, 2 blue
# ['Game 1: 4 green', ' 2 blue']
#  4 green
#
# 4
#
# g
# r
# e
# e
# n
#
# The number of green cubes is:  4
# next   4 green
#  2 blue
#
# 2
#
# b
# l
# u
# e
#
# The number of blue cubes is:  2
#  1 red, 1 blue, 4 green
# [' 1 red', ' 1 blue', ' 4 green']
#  1 red
#
# 1
#
# r
# e
# d
#
# The number of red cubes is:  1
#  1 blue
#
# 1
#
# b
# l
# u
# e
#
# The number of blue cubes is:  1
#  4 green
#
# 4
#
# g
# r
# e
# e
# n
#
# The number of green cubes is:  4
# next   4 green
#  3 green, 4 blue, 1 red
# [' 3 green', ' 4 blue', ' 1 red']
#  3 green
#
# 3
#
# g
# r
# e
# e
# n
#
# The number of green cubes is:  3
# next   3 green
#  4 blue
#
# 4
#
# b
# l
# u
# e
#
# ...

# %%
lulu='4 green'
print(int(lulu))
if 'green'in lulu:
    number_string=''
    for char in lulu:
        print(char)
        if char.isdigit():
            number_string=char+number_string
            num=int(number_string)
    
    print(number_string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 2
#       1 lulu='4 green'
# ----> 2 print(int(lulu))
#       3 if 'green'in lulu:
#       4     number_string=''
#
# ValueError: invalid literal for int() with base 10: '4 green'
