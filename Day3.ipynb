# %% [markdown]
# # DAY 3
# The engine schematic (your puzzle input) consists of a visual representation of the engine. There are lots of numbers and symbols you don't really understand, but apparently any number adjacent to a symbol, even diagonally, is a "part number" and should be included in your sum. (Periods (.) do not count as a symbol.)
# In this schematic, two numbers are not part numbers because they are not adjacent to a symbol: 114 (top right) and 58 (middle right). Every other number is adjacent to a symbol and so is a part number; their sum is 4361.
#
# Of course, the actual engine schematic is much larger. What is the sum of all of the part numbers in the engine schematic?

# %%
import os
import math
os.getcwd()
# Out:
# 'C:\\Users\\Pilar\\Documents\\CURSO PYTHON\\AdventOfCode'

# %%
def create_matrix():

# %%
def ret_num(real):
    number_string=''
    num=[]
    pos=[]
    longitudes=[]
    for i,char in enumerate(real):
        #print(char)
        if char.isdigit():
            if i==0:
                pos.append(i)
            if real[i-1].isdigit()==False and i>0:
                pos.append(i)
            number_string=number_string+char
            number=int(number_string)
            long=len(number_string)
            if real[i+1].isdigit()==False and i<len(real):
                num.append(number)
                longitudes.append(long)
                number_string=''
    return num,longitudes,pos

# %%
def digits_to_numbers(line):
    (numeros,long,posiciones)=ret_num(lines[0])
    #print('\nNumeros presentes: ', numeros, '\nPosiciones: ', posiciones, '\nLongitud c/n: ', long)
    lista_s=list(line)
    #print(lista_s)
    lista_m=lista_s
    for i,numero in enumerate(numeros):
        lista_m[posiciones[i]]=numero
        for char in range(long[i]):
            lista_m[posiciones[i]+char+1]='.'
    return lista_m

# %%
def to_list(line):
    lista=list(line)
    return lista

# %%
def to_matrix(lines):
    mtx=[]
    for line in lines:
        mtx.append(to_list(line))
    return(mtx)

# %%
def check_symbol(char):
    yes=False
    symbols=['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', 
             '.', '/', ':', ';', '<', '=', '>', '?', '@']
    for symbol in symbols:
        if char==symbol:
            yes=True
    return yes

# %%
def list_nums(row,pos):
    n_s=[]
    for nums in range(pos,len(row)):
        if row[nums].isdigit()==True:
            n_s.append(row[nums])
    return n_s

# %%
def list_to_number(lista):
    n_s=''
    for numbers in lista:
        n_s=n_s+numbers
    return int(n_s)

# %%
def detect_numbers(mtx):
    cont=False
    is_num=False
    numeros=[]
    for j,rows in enumerate(mtx):
        for (i,chars) in enumerate(rows):
            if char.isdigit()==True:
                if j==0:
                    if i==0:
                        list_num=list_nums(rows,i)
                        if check_symbol(mtx[j][i+1])==True or check_symbol(mtx[j+1][i+1])==True or check_symbol(mtx[j+1][i])==True:
                            numeros.append(list_to_number(list_num))
                            for l in range(i,i+len(list_num))
                                row[l]='.'
                    elif():
                        if rows[i-1].isdigit()==False:
                            list_num=list_nums(rows,i)
                        elif:
                            list_num=list_nums(rows,i-1)
                            if check_symbol(mtx[j][i+1])==True or check_symbol(mtx[j+1][i+1])==True 
                            or check_symbol(mtx[j+1][i])==True or check_symbol(mtx[j][i-1]) or check_symbol(mtx[j+1][i-1]):
                                numeros.append(list_to_number(list_num))
                                for l in range(i,i+len(list_num))
                                    row[l]='.'
                    elif i==len(row):
                        if rows[i-1].isdigit()==False:
                            list_num=list_nums(rows,i)
                            if check_symbol(mtx[j+1][i])==True or check_symbol(mtx[j][i-1]) or check_symbol(mtx[j+1][i-1]):
                                numeros.append(list_to_number(list_num))
                        
                    
            if row==len(mtx):

# %%
file = open('Day3.txt', 'r')
lines=file.readlines()
matrix=to_matrix(lines)
print(len(matrix))
print(matrix)
# print(lines[0])
# print('\n')
# print(lines[1])
# print('\n')
# print(lines[2])
# print('\n')
# print('\n')
# l1=digits_to_numbers(lines[0])
# l2=digits_to_numbers(lines[1])
# l3=digits_to_numbers(lines[2])
# print(l1)
# print('\n')
# print(l2)
# print('\n')
# print(l3)
# Out:
# 140
# ...
